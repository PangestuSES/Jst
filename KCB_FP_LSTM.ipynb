# %%
# import library
import pandas as pd
import numpy as np
# cleaning data
from sklearn.preprocessing import LabelEncoder

# %%
# membaca data set dari file csv
from google.colab import drive
drive.mount('/content/drive')

path = "/content/drive/MyDrive/Colab Notebooks/seattle-weather.csv"
df = pd.read_csv(path)

df.head(10)
# Out:
# Mounted at /content/drive
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain
# 5  2012-01-06            2.5       4.4       2.2   2.2     rain
# 6  2012-01-07            0.0       7.2       2.8   2.3     rain
# 7  2012-01-08            0.0      10.0       2.8   2.0      sun
# 8  2012-01-09            4.3       9.4       5.0   3.4     rain
# 9  2012-01-10            1.0       6.1       0.6   3.4     rain

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Membuat chart untuk isi data
sns.countplot(data=df,x="weather")
plt.show();

# %%
# Melihat Persentase taget dari dataset
countrain=len(df[df.weather=="rain"])
countsun=len(df[df.weather=="sun"])
countdrizzle=len(df[df.weather=="drizzle"])
countsnow=len(df[df.weather=="snow"])
countfog=len(df[df.weather=="fog"])
print("Percent of Rain\t\t: {:.2f}%".format((countrain/(len(df.weather))*100)))
print("Percent of Sun\t\t: {:.2f}%".format((countsun/(len(df.weather))*100)))
print("Percent of Drizzle\t: {:.2f}%".format((countdrizzle/(len(df.weather))*100)))
print("Percent of Snow\t\t: {:.2f}%".format((countsnow/(len(df.weather))*100)))
print("Percent of Fog\t\t: {:.2f}%".format((countfog/(len(df.weather))*100)))
# Out:
# Percent of Rain		: 43.87%
# Percent of Sun		: 43.81%
# Percent of Drizzle	: 3.63%
# Percent of Snow		: 1.78%
# Percent of Fog		: 6.91%

# %%
#Pembulatan Precipitation
pengendapan = []

for pt in df['precipitation']:
  #tambah nilai
  pengendapan.append(round(pt))

df['precipitation-round']=pengendapan

temp_cols = df.columns.tolist()
index = df.columns.get_loc("precipitation")
pengendapan_index = df.columns.get_loc("precipitation-round")


new_cols1 = (
    temp_cols[:index] +
    temp_cols[pengendapan_index:pengendapan_index+1] +
    temp_cols[index+1:pengendapan_index]
)

df = df[new_cols1]

df.head(5)
# Out:
#          date  precipitation-round  temp_max  temp_min  wind  weather
# 0  2012-01-01                    0      12.8       5.0   4.7  drizzle
# 1  2012-01-02                   11      10.6       2.8   4.5     rain
# 2  2012-01-03                    1      11.7       7.2   2.3     rain
# 3  2012-01-04                   20      12.2       5.6   4.7     rain
# 4  2012-01-05                    1       8.9       2.8   6.1     rain

# %%
#Pembulatan temp_min
suhu_min = []

for s_min in df['temp_min']:
  #tambah nilai
  suhu_min.append(round(s_min))

df['temp_min-round']=suhu_min

temp_cols = df.columns.tolist()
index = df.columns.get_loc("temp_min")
suhu_min_index = df.columns.get_loc("temp_min-round")


new_cols2 = (
    temp_cols[:index] +
    temp_cols[suhu_min_index:suhu_min_index+1] +
    temp_cols[index+1:suhu_min_index]
)

df = df[new_cols2]

df.head(5)
# Out:
#          date  precipitation-round  temp_max  temp_min-round  wind  weather
# 0  2012-01-01                    0      12.8               5   4.7  drizzle
# 1  2012-01-02                   11      10.6               3   4.5     rain
# 2  2012-01-03                    1      11.7               7   2.3     rain
# 3  2012-01-04                   20      12.2               6   4.7     rain
# 4  2012-01-05                    1       8.9               3   6.1     rain

# %%
#Pembulatan temp_max
suhu_max = []

for s_max in df['temp_max']:
  #tambah nilai
  suhu_max.append(round(s_max))

df['temp_max-round']=suhu_max

temp_cols = df.columns.tolist()
index = df.columns.get_loc("temp_max")
suhu_max_index = df.columns.get_loc("temp_max-round")


new_cols3 = (
    temp_cols[:index] +
    temp_cols[suhu_max_index:suhu_max_index+1] +
    temp_cols[index+1:suhu_max_index]
)

df = df[new_cols3]

df.head(5)
# Out:
#          date  precipitation-round  temp_max-round  temp_min-round  wind  \
# 0  2012-01-01                    0              13               5   4.7
# 1  2012-01-02                   11              11               3   4.5
# 2  2012-01-03                    1              12               7   2.3
# 3  2012-01-04                   20              12               6   4.7
# 4  2012-01-05                    1               9               3   6.1
#
#    weather
# 0  drizzle
# 1     rain
# 2     rain
# 3     rain
# 4     rain

# %%
#Pembulatan wind
angin = []

for agn in df['wind']:
  #tambah nilai
  angin.append(round(agn))

df['wind-round']=angin

temp_cols = df.columns.tolist()
index = df.columns.get_loc("wind")
angin_index = df.columns.get_loc("wind-round")


new_cols4 = (
    temp_cols[:index] +
    temp_cols[angin_index:angin_index+1] +
    temp_cols[index+1:angin_index]
)

df = df[new_cols4]

df.head(5)
# Out:
#          date  precipitation-round  temp_max-round  temp_min-round  \
# 0  2012-01-01                    0              13               5
# 1  2012-01-02                   11              11               3
# 2  2012-01-03                    1              12               7
# 3  2012-01-04                   20              12               6
# 4  2012-01-05                    1               9               3
#
#    wind-round  weather
# 0           5  drizzle
# 1           4     rain
# 2           2     rain
# 3           5     rain
# 4           6     rain

# %%
#Slicing Bulan contoh 2012-03-01 ->
bulan = []

for bl in df['date']:
  #tambah bulan
  bulan.append(int(bl[5:7]))  #"03" -> 3

df['date-bulan']=bulan

temp_cols = df.columns.tolist()
index = df.columns.get_loc("date")
bulan_index = df.columns.get_loc("date-bulan")


new_cols5 = (
    temp_cols[:index] +
    temp_cols[bulan_index:bulan_index+1] +
    temp_cols[index+1:bulan_index]
)

df = df[new_cols5]

df.head(5)
# Out:
#    date-bulan  precipitation-round  temp_max-round  temp_min-round  \
# 0           1                    0              13               5
# 1           1                   11              11               3
# 2           1                    1              12               7
# 3           1                   20              12               6
# 4           1                    1               9               3
#
#    wind-round  weather
# 0           5  drizzle
# 1           4     rain
# 2           2     rain
# 3           5     rain
# 4           6     rain

# %%
#encoder
enc = LabelEncoder()

# weather [0 -> Drizzle, 1 -> fog, 2-> rain, 3 -> snow, 4 -> sun]
df.weather = enc.fit_transform(df.weather.values)
display(df.iloc[192])
# Out:
# date-bulan              7
# precipitation-round     0
# temp_max-round         28
# temp_min-round         13
# wind-round              3
# weather                 1
# Name: 192, dtype: int64

# %%
#data
df.head(200)
# Out:
#      date-bulan  precipitation-round  temp_max-round  temp_min-round  \
# 0             1                    0              13               5
# 1             1                   11              11               3
# 2             1                    1              12               7
# 3             1                   20              12               6
# 4             1                    1               9               3
# ..          ...                  ...             ...             ...
# 195           7                    0              25              15
# 196           7                    0              19              13
# 197           7                    0              26              13
# 198           7                    0              22              15
# 199           7                    0              21              14
#
#      wind-round  weather
# 0             5        0
# 1             4        2
# 2             2        2
# 3             5        2
# 4             6        2
# ..          ...      ...
# 195           2        2
# 196           4        2
# 197           2        2
# 198           3        4
# 199           3        4
#
# [200 rows x 6 columns]

# %%
#Mendapatkan ukuran csv

size_data = len(df)

#Membagi untuk data latih (80%)
train = round(size_data*0.8)
train_set = df[:train]


#membagi untuk data uji (20%)
test_set = df[train:]

# %%
# Alokasikan sampel data latih
x_train = train_set[[
    'date-bulan',
    'precipitation-round',
    'temp_max-round',
    'temp_min-round',
    'wind-round',
    ]].values
y_train = train_set.weather.values



type(x_train) # numpy.ndarray
# Out:
# numpy.ndarray

# %%
# Model architecture Neural Network

import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense
from keras.layers import LSTM

model = Sequential([
    LSTM(units = 25, input_shape= (5,1), activation = 'elu'),
    Dense(units = 50, activation = 'elu'),
    Dense(units = 5, activation = 'softmax')
])

# %% [markdown]
# ## Fungsi aktivasi Elu menggabungkan karakteristik dari fungsi ReLU dan fungsi sigmoid. Fungsi aktivasi Elu mengatasi masalah ini dengan mengizinkan nilai negatif pada input neuron.
#
# ## Fungsi aktivasi Softmax adalah fungsi yang umum digunakan dalam jaringan saraf tiruan untuk masalah klasifikasi multikelas. Fungsi ini mengubah keluaran dari lapisan terakhir jaringan menjadi distribusi probabilitas yang menjumlahkan menjadi 1, dengan setiap elemen probabilitas yang merepresentasikan peluang kelas tertentu.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 25)                2700
#
#  dense (Dense)               (None, 50)                1300
#
#  dense_1 (Dense)             (None, 5)                 255
#
# =================================================================
# Total params: 4,255
# Trainable params: 4,255
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.optimizers import Adamax

model.compile(loss = 'sparse_categorical_crossentropy', optimizer= Adamax(learning_rate = 0.0001),
              metrics = ['accuracy']
             )

# %% [markdown]
# ## Adamax: Variasi dari optimizer Adam yang lebih stabil dalam kasus jaringan dengan parameter yang besar.

# %%
# training the model
LSTM_history = model.fit(x = x_train,
                         y = y_train,
                         batch_size= 10,
                         epochs = 100,
                         validation_split= 0.1,
                         shuffle = True,
                         verbose = 2)
# Out:
# Epoch 1/100
# 106/106 - 2s - loss: 1.9091 - accuracy: 0.2662 - val_loss: 1.8592 - val_accuracy: 0.2564 - 2s/epoch - 18ms/step
# Epoch 2/100
# 106/106 - 0s - loss: 1.5596 - accuracy: 0.4420 - val_loss: 1.5959 - val_accuracy: 0.2564 - 258ms/epoch - 2ms/step
# Epoch 3/100
# 106/106 - 0s - loss: 1.3296 - accuracy: 0.4420 - val_loss: 1.4105 - val_accuracy: 0.2564 - 283ms/epoch - 3ms/step
# Epoch 4/100
# 106/106 - 0s - loss: 1.1859 - accuracy: 0.4382 - val_loss: 1.2923 - val_accuracy: 0.2393 - 313ms/epoch - 3ms/step
# Epoch 5/100
# 106/106 - 0s - loss: 1.1112 - accuracy: 0.4411 - val_loss: 1.2323 - val_accuracy: 0.2906 - 283ms/epoch - 3ms/step
# Epoch 6/100
# 106/106 - 0s - loss: 1.0749 - accuracy: 0.5409 - val_loss: 1.2071 - val_accuracy: 0.4274 - 290ms/epoch - 3ms/step
# Epoch 7/100
# 106/106 - 0s - loss: 1.0565 - accuracy: 0.6103 - val_loss: 1.1968 - val_accuracy: 0.4872 - 273ms/epoch - 3ms/step
# Epoch 8/100
# 106/106 - 0s - loss: 1.0459 - accuracy: 0.6065 - val_loss: 1.1994 - val_accuracy: 0.4872 - 325ms/epoch - 3ms/step
# Epoch 9/100
# 106/106 - 0s - loss: 1.0380 - accuracy: 0.6112 - val_loss: 1.1967 - val_accuracy: 0.4957 - 298ms/epoch - 3ms/step
# Epoch 10/100
# 106/106 - 0s - loss: 1.0314 - accuracy: 0.6008 - val_loss: 1.1931 - val_accuracy: 0.4957 - 260ms/epoch - 2ms/step
# Epoch 11/100
# 106/106 - 0s - loss: 1.0260 - accuracy: 0.6084 - val_loss: 1.1916 - val_accuracy: 0.4957 - 312ms/epoch - 3ms/step
# Epoch 12/100
# 106/106 - 0s - loss: 1.0202 - accuracy: 0.6112 - val_loss: 1.1833 - val_accuracy: 0.5043 - 286ms/epoch - 3ms/step
# Epoch 13/100
# 106/106 - 0s - loss: 1.0150 - accuracy: 0.6046 - val_loss: 1.1880 - val_accuracy: 0.4957 - 277ms/epoch - 3ms/step
# Epoch 14/100
# 106/106 - 0s - loss: 1.0101 - accuracy: 0.6112 - val_loss: 1.1845 - val_accuracy: 0.5043 - 292ms/epoch - 3ms/step
# Epoch 15/100
# 106/106 - 0s - loss: 1.0052 - accuracy: 0.6122 - val_loss: 1.1834 - val_accuracy: 0.5043 - 286ms/epoch - 3ms/step
# Epoch 16/100
# 106/106 - 0s - loss: 1.0006 - accuracy: 0.6179 - val_loss: 1.1779 - val_accuracy: 0.5128 - 322ms/epoch - 3ms/step
# Epoch 17/100
# 106/106 - 0s - loss: 0.9961 - accuracy: 0.6131 - val_loss: 1.1779 - val_accuracy: 0.5128 - 370ms/epoch - 3ms/step
# Epoch 18/100
# 106/106 - 0s - loss: 0.9918 - accuracy: 0.6169 - val_loss: 1.1740 - val_accuracy: 0.5214 - 332ms/epoch - 3ms/step
# Epoch 19/100
# 106/106 - 0s - loss: 0.9878 - accuracy: 0.6207 - val_loss: 1.1704 - val_accuracy: 0.5214 - 377ms/epoch - 4ms/step
# Epoch 20/100
# 106/106 - 0s - loss: 0.9833 - accuracy: 0.6226 - val_loss: 1.1711 - val_accuracy: 0.5214 - 358ms/epoch - 3ms/step
# Epoch 21/100
# 106/106 - 0s - loss: 0.9799 - accuracy: 0.6179 - val_loss: 1.1720 - val_accuracy: 0.5214 - 409ms/epoch - 4ms/step
# Epoch 22/100
# 106/106 - 0s - loss: 0.9749 - accuracy: 0.6226 - val_loss: 1.1713 - val_accuracy: 0.5128 - 343ms/epoch - 3ms/step
# Epoch 23/100
# 106/106 - 0s - loss: 0.9704 - accuracy: 0.6255 - val_loss: 1.1649 - val_accuracy: 0.5299 - 389ms/epoch - 4ms/step
# Epoch 24/100
# 106/106 - 0s - loss: 0.9660 - accuracy: 0.6302 - val_loss: 1.1634 - val_accuracy: 0.5470 - 389ms/epoch - 4ms/step
# Epoch 25/100
# 106/106 - 0s - loss: 0.9614 - accuracy: 0.6312 - val_loss: 1.1625 - val_accuracy: 0.5385 - 299ms/epoch - 3ms/step
# Epoch 26/100
# 106/106 - 0s - loss: 0.9575 - accuracy: 0.6369 - val_loss: 1.1595 - val_accuracy: 0.5470 - 292ms/epoch - 3ms/step
# Epoch 27/100
# 106/106 - 0s - loss: 0.9531 - accuracy: 0.6397 - val_loss: 1.1545 - val_accuracy: 0.5470 - 252ms/epoch - 2ms/step
# Epoch 28/100
# 106/106 - 0s - loss: 0.9484 - accuracy: 0.6445 - val_loss: 1.1531 - val_accuracy: 0.5556 - 272ms/epoch - 3ms/step
# Epoch 29/100
# 106/106 - 0s - loss: 0.9441 - accuracy: 0.6511 - val_loss: 1.1490 - val_accuracy: 0.5641 - 298ms/epoch - 3ms/step
# Epoch 30/100
# 106/106 - 0s - loss: 0.9394 - accuracy: 0.6502 - val_loss: 1.1460 - val_accuracy: 0.5641 - 287ms/epoch - 3ms/step
# Epoch 31/100
# 106/106 - 0s - loss: 0.9347 - accuracy: 0.6540 - val_loss: 1.1482 - val_accuracy: 0.5812 - 264ms/epoch - 2ms/step
# Epoch 32/100
# 106/106 - 0s - loss: 0.9305 - accuracy: 0.6568 - val_loss: 1.1448 - val_accuracy: 0.5812 - 290ms/epoch - 3ms/step
# Epoch 33/100
# 106/106 - 0s - loss: 0.9255 - accuracy: 0.6635 - val_loss: 1.1390 - val_accuracy: 0.5897 - 252ms/epoch - 2ms/step
# Epoch 34/100
# 106/106 - 0s - loss: 0.9204 - accuracy: 0.6587 - val_loss: 1.1365 - val_accuracy: 0.5897 - 280ms/epoch - 3ms/step
# Epoch 35/100
# 106/106 - 0s - loss: 0.9157 - accuracy: 0.6673 - val_loss: 1.1331 - val_accuracy: 0.5726 - 286ms/epoch - 3ms/step
# Epoch 36/100
# 106/106 - 0s - loss: 0.9109 - accuracy: 0.6663 - val_loss: 1.1292 - val_accuracy: 0.5812 - 264ms/epoch - 2ms/step
# Epoch 37/100
# 106/106 - 0s - loss: 0.9062 - accuracy: 0.6702 - val_loss: 1.1283 - val_accuracy: 0.5812 - 263ms/epoch - 2ms/step
# Epoch 38/100
# 106/106 - 0s - loss: 0.9018 - accuracy: 0.6863 - val_loss: 1.1254 - val_accuracy: 0.5812 - 254ms/epoch - 2ms/step
# Epoch 39/100
# 106/106 - 0s - loss: 0.8969 - accuracy: 0.6863 - val_loss: 1.1213 - val_accuracy: 0.5897 - 268ms/epoch - 3ms/step
# Epoch 40/100
# 106/106 - 0s - loss: 0.8926 - accuracy: 0.6901 - val_loss: 1.1192 - val_accuracy: 0.5897 - 300ms/epoch - 3ms/step
# Epoch 41/100
# 106/106 - 0s - loss: 0.8876 - accuracy: 0.6977 - val_loss: 1.1159 - val_accuracy: 0.5897 - 275ms/epoch - 3ms/step
# Epoch 42/100
# 106/106 - 0s - loss: 0.8831 - accuracy: 0.6930 - val_loss: 1.1114 - val_accuracy: 0.5897 - 285ms/epoch - 3ms/step
# Epoch 43/100
# 106/106 - 0s - loss: 0.8788 - accuracy: 0.6996 - val_loss: 1.1080 - val_accuracy: 0.5897 - 282ms/epoch - 3ms/step
# Epoch 44/100
# 106/106 - 0s - loss: 0.8741 - accuracy: 0.6987 - val_loss: 1.1050 - val_accuracy: 0.5897 - 295ms/epoch - 3ms/step
# Epoch 45/100
# 106/106 - 0s - loss: 0.8684 - accuracy: 0.7053 - val_loss: 1.1049 - val_accuracy: 0.6068 - 276ms/epoch - 3ms/step
# Epoch 46/100
# 106/106 - 0s - loss: 0.8636 - accuracy: 0.7120 - val_loss: 1.1013 - val_accuracy: 0.6068 - 287ms/epoch - 3ms/step
# Epoch 47/100
# 106/106 - 0s - loss: 0.8582 - accuracy: 0.7148 - val_loss: 1.0977 - val_accuracy: 0.6068 - 270ms/epoch - 3ms/step
# Epoch 48/100
# 106/106 - 0s - loss: 0.8530 - accuracy: 0.7091 - val_loss: 1.0946 - val_accuracy: 0.6068 - 295ms/epoch - 3ms/step
# Epoch 49/100
# 106/106 - 0s - loss: 0.8474 - accuracy: 0.7205 - val_loss: 1.0897 - val_accuracy: 0.5983 - 294ms/epoch - 3ms/step
# Epoch 50/100
# 106/106 - 0s - loss: 0.8421 - accuracy: 0.7158 - val_loss: 1.0882 - val_accuracy: 0.6154 - 261ms/epoch - 2ms/step
# Epoch 51/100
# 106/106 - 0s - loss: 0.8370 - accuracy: 0.7262 - val_loss: 1.0871 - val_accuracy: 0.6154 - 257ms/epoch - 2ms/step
# Epoch 52/100
# 106/106 - 0s - loss: 0.8323 - accuracy: 0.7272 - val_loss: 1.0841 - val_accuracy: 0.6239 - 270ms/epoch - 3ms/step
# Epoch 53/100
# 106/106 - 0s - loss: 0.8275 - accuracy: 0.7310 - val_loss: 1.0823 - val_accuracy: 0.6239 - 251ms/epoch - 2ms/step
# Epoch 54/100
# 106/106 - 0s - loss: 0.8222 - accuracy: 0.7319 - val_loss: 1.0791 - val_accuracy: 0.6239 - 268ms/epoch - 3ms/step
# Epoch 55/100
# 106/106 - 0s - loss: 0.8168 - accuracy: 0.7357 - val_loss: 1.0760 - val_accuracy: 0.6239 - 262ms/epoch - 2ms/step
# Epoch 56/100
# 106/106 - 0s - loss: 0.8124 - accuracy: 0.7414 - val_loss: 1.0750 - val_accuracy: 0.6239 - 273ms/epoch - 3ms/step
# Epoch 57/100
# 106/106 - 0s - loss: 0.8077 - accuracy: 0.7376 - val_loss: 1.0747 - val_accuracy: 0.6239 - 288ms/epoch - 3ms/step
# Epoch 58/100
# 106/106 - 0s - loss: 0.8030 - accuracy: 0.7424 - val_loss: 1.0684 - val_accuracy: 0.6239 - 259ms/epoch - 2ms/step
# Epoch 59/100
# 106/106 - 0s - loss: 0.7989 - accuracy: 0.7414 - val_loss: 1.0650 - val_accuracy: 0.6239 - 300ms/epoch - 3ms/step
# Epoch 60/100
# 106/106 - 0s - loss: 0.7944 - accuracy: 0.7433 - val_loss: 1.0650 - val_accuracy: 0.6239 - 422ms/epoch - 4ms/step
# Epoch 61/100
# 106/106 - 0s - loss: 0.7902 - accuracy: 0.7490 - val_loss: 1.0616 - val_accuracy: 0.6239 - 331ms/epoch - 3ms/step
# Epoch 62/100
# 106/106 - 0s - loss: 0.7865 - accuracy: 0.7471 - val_loss: 1.0585 - val_accuracy: 0.6239 - 382ms/epoch - 4ms/step
# Epoch 63/100
# 106/106 - 0s - loss: 0.7819 - accuracy: 0.7462 - val_loss: 1.0595 - val_accuracy: 0.6239 - 356ms/epoch - 3ms/step
# Epoch 64/100
# 106/106 - 0s - loss: 0.7773 - accuracy: 0.7452 - val_loss: 1.0580 - val_accuracy: 0.6239 - 344ms/epoch - 3ms/step
# Epoch 65/100
# 106/106 - 0s - loss: 0.7736 - accuracy: 0.7510 - val_loss: 1.0564 - val_accuracy: 0.6496 - 329ms/epoch - 3ms/step
# Epoch 66/100
# 106/106 - 0s - loss: 0.7699 - accuracy: 0.7529 - val_loss: 1.0529 - val_accuracy: 0.6239 - 410ms/epoch - 4ms/step
# Epoch 67/100
# 106/106 - 0s - loss: 0.7661 - accuracy: 0.7538 - val_loss: 1.0534 - val_accuracy: 0.6496 - 356ms/epoch - 3ms/step
# Epoch 68/100
# 106/106 - 0s - loss: 0.7628 - accuracy: 0.7595 - val_loss: 1.0520 - val_accuracy: 0.6496 - 238ms/epoch - 2ms/step
# Epoch 69/100
# 106/106 - 0s - loss: 0.7595 - accuracy: 0.7567 - val_loss: 1.0504 - val_accuracy: 0.6410 - 282ms/epoch - 3ms/step
# Epoch 70/100
# 106/106 - 0s - loss: 0.7556 - accuracy: 0.7595 - val_loss: 1.0502 - val_accuracy: 0.6581 - 265ms/epoch - 3ms/step
# Epoch 71/100
# 106/106 - 0s - loss: 0.7527 - accuracy: 0.7633 - val_loss: 1.0485 - val_accuracy: 0.6496 - 241ms/epoch - 2ms/step
# Epoch 72/100
# 106/106 - 0s - loss: 0.7487 - accuracy: 0.7624 - val_loss: 1.0491 - val_accuracy: 0.6581 - 272ms/epoch - 3ms/step
# Epoch 73/100
# 106/106 - 0s - loss: 0.7456 - accuracy: 0.7624 - val_loss: 1.0438 - val_accuracy: 0.6496 - 301ms/epoch - 3ms/step
# Epoch 74/100
# 106/106 - 0s - loss: 0.7425 - accuracy: 0.7595 - val_loss: 1.0433 - val_accuracy: 0.6496 - 275ms/epoch - 3ms/step
# Epoch 75/100
# 106/106 - 0s - loss: 0.7398 - accuracy: 0.7614 - val_loss: 1.0438 - val_accuracy: 0.6496 - 266ms/epoch - 3ms/step
# Epoch 76/100
# 106/106 - 0s - loss: 0.7373 - accuracy: 0.7595 - val_loss: 1.0448 - val_accuracy: 0.6667 - 325ms/epoch - 3ms/step
# Epoch 77/100
# 106/106 - 0s - loss: 0.7350 - accuracy: 0.7605 - val_loss: 1.0430 - val_accuracy: 0.6667 - 253ms/epoch - 2ms/step
# Epoch 78/100
# 106/106 - 0s - loss: 0.7327 - accuracy: 0.7624 - val_loss: 1.0444 - val_accuracy: 0.6667 - 247ms/epoch - 2ms/step
# Epoch 79/100
# 106/106 - 0s - loss: 0.7308 - accuracy: 0.7633 - val_loss: 1.0419 - val_accuracy: 0.6581 - 287ms/epoch - 3ms/step
# Epoch 80/100
# 106/106 - 0s - loss: 0.7283 - accuracy: 0.7633 - val_loss: 1.0423 - val_accuracy: 0.6667 - 278ms/epoch - 3ms/step
# Epoch 81/100
# 106/106 - 0s - loss: 0.7264 - accuracy: 0.7605 - val_loss: 1.0433 - val_accuracy: 0.6667 - 284ms/epoch - 3ms/step
# Epoch 82/100
# 106/106 - 0s - loss: 0.7236 - accuracy: 0.7652 - val_loss: 1.0401 - val_accuracy: 0.6667 - 304ms/epoch - 3ms/step
# Epoch 83/100
# 106/106 - 0s - loss: 0.7223 - accuracy: 0.7633 - val_loss: 1.0412 - val_accuracy: 0.6667 - 270ms/epoch - 3ms/step
# Epoch 84/100
# 106/106 - 0s - loss: 0.7192 - accuracy: 0.7652 - val_loss: 1.0400 - val_accuracy: 0.6667 - 440ms/epoch - 4ms/step
# Epoch 85/100
# 106/106 - 0s - loss: 0.7171 - accuracy: 0.7643 - val_loss: 1.0386 - val_accuracy: 0.6667 - 489ms/epoch - 5ms/step
# Epoch 86/100
# 106/106 - 0s - loss: 0.7150 - accuracy: 0.7652 - val_loss: 1.0393 - val_accuracy: 0.6667 - 268ms/epoch - 3ms/step
# Epoch 87/100
# 106/106 - 0s - loss: 0.7124 - accuracy: 0.7662 - val_loss: 1.0374 - val_accuracy: 0.6667 - 246ms/epoch - 2ms/step
# Epoch 88/100
# 106/106 - 0s - loss: 0.7100 - accuracy: 0.7633 - val_loss: 1.0397 - val_accuracy: 0.6581 - 259ms/epoch - 2ms/step
# Epoch 89/100
# 106/106 - 0s - loss: 0.7084 - accuracy: 0.7624 - val_loss: 1.0391 - val_accuracy: 0.6581 - 263ms/epoch - 2ms/step
# Epoch 90/100
# 106/106 - 0s - loss: 0.7064 - accuracy: 0.7662 - val_loss: 1.0371 - val_accuracy: 0.6667 - 253ms/epoch - 2ms/step
# Epoch 91/100
# 106/106 - 0s - loss: 0.7048 - accuracy: 0.7690 - val_loss: 1.0381 - val_accuracy: 0.6581 - 294ms/epoch - 3ms/step
# Epoch 92/100
# 106/106 - 0s - loss: 0.7017 - accuracy: 0.7681 - val_loss: 1.0366 - val_accuracy: 0.6667 - 269ms/epoch - 3ms/step
# Epoch 93/100
# 106/106 - 0s - loss: 0.7010 - accuracy: 0.7652 - val_loss: 1.0360 - val_accuracy: 0.6667 - 280ms/epoch - 3ms/step
# Epoch 94/100
# 106/106 - 0s - loss: 0.6988 - accuracy: 0.7681 - val_loss: 1.0360 - val_accuracy: 0.6667 - 253ms/epoch - 2ms/step
# Epoch 95/100
# 106/106 - 0s - loss: 0.6969 - accuracy: 0.7681 - val_loss: 1.0364 - val_accuracy: 0.6581 - 312ms/epoch - 3ms/step
# Epoch 96/100
# 106/106 - 0s - loss: 0.6954 - accuracy: 0.7690 - val_loss: 1.0346 - val_accuracy: 0.6581 - 257ms/epoch - 2ms/step
# Epoch 97/100
# 106/106 - 0s - loss: 0.6937 - accuracy: 0.7681 - val_loss: 1.0355 - val_accuracy: 0.6581 - 285ms/epoch - 3ms/step
# Epoch 98/100
# 106/106 - 0s - loss: 0.6924 - accuracy: 0.7662 - val_loss: 1.0343 - val_accuracy: 0.6667 - 271ms/epoch - 3ms/step
# Epoch 99/100
# 106/106 - 0s - loss: 0.6902 - accuracy: 0.7681 - val_loss: 1.0343 - val_accuracy: 0.6581 - 320ms/epoch - 3ms/step
# Epoch 100/100
# 106/106 - 0s - loss: 0.6893 - accuracy: 0.7643 - val_loss: 1.0370 - val_accuracy: 0.6581 - 264ms/epoch - 2ms/step

# %%
# Grafik Perbandingan Training dan Validation
acc = LSTM_history.history['accuracy']
val_acc = LSTM_history.history['val_accuracy']

loss = LSTM_history.history['loss']
val_loss = LSTM_history.history['val_loss']

plt.figure(figsize=(12, 12))

plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy', color='r')
plt.plot(val_acc, label='Validation Accuracy', color='b')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='lower right', fontsize=13)
plt.ylabel('Accuracy', fontsize=16, weight='bold')
plt.title('LSTM - Training & Validation Acc.', fontsize=16, weight='bold')
plt.xlabel('Epoch', fontsize=15, weight='bold')
plt.subplots_adjust(hspace=0.5)
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss', color='r')
plt.plot(val_loss, label='Validation Loss', color='b')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='upper right', fontsize=13)
plt.ylabel('Cross Entropy', fontsize=16, weight='bold')
plt.title('LSTM - Training & Validation Loss', fontsize=15, weight='bold')
plt.xlabel('Epoch', fontsize=15, weight='bold')

plt.show()

# %%
# alokasi sampel data uji
x_test = test_set[[
    'date-bulan',
    'precipitation-round',
    'temp_max-round',
    'temp_min-round',
    'wind-round',
    ]].values
y_test = test_set.weather.values


type(x_test) # numpy.ndarray
print(x_test)
# Out:
# [[ 3 56 11  6  4]
#  [ 3  1 14  6  3]
#  [ 3  1 13  4  3]
#  ...
#  [12  0  7  1  3]
#  [12  0  6 -1  3]
#  [12  0  6 -2  4]]

# %%
# Model Prediction
predictions = model.predict(x = x_test,
                            batch_size= 10,
                            verbose=0)
print(predictions)
# Out:
# [[0.00331611 0.00320066 0.2822256  0.00429534 0.7069623 ]
#  [0.04462201 0.03021089 0.60783035 0.03458967 0.28274706]
#  [0.05779198 0.03246293 0.52623034 0.04754872 0.335966  ]
#  ...
#  [0.08076841 0.03635048 0.1941777  0.06154237 0.62716097]
#  [0.09858736 0.03709884 0.09505259 0.05628785 0.71297336]
#  [0.09602566 0.03008309 0.0614483  0.04744639 0.7649965 ]]

# %%
# Model Evaluate
accuracy = model.evaluate(x_test, y_test)
# Out:
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7206 - accuracy: 0.7842

# %%
# ringkasan dari metrik evaluasi untuk tugas klasifikasi
from sklearn.metrics import classification_report

y_pred = np.argmax(predictions, axis=1)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         7
#            1       0.00      0.00      0.00        31
#            2       0.89      0.84      0.87       109
#            4       0.72      0.94      0.82       145
#
#     accuracy                           0.78       292
#    macro avg       0.40      0.45      0.42       292
# weighted avg       0.69      0.78      0.73       292
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Menghitung nilai akurasi dengan index prediksi dengan kemungkinan tertinggi
rounded_pred = np.argmax(predictions, axis = 1)

count = 0
for i in range(len(rounded_pred)):
  row = test_set.iloc[i]
  if rounded_pred[i] == row['weather']:
    count += 1

print("%.2f" %(count/len(rounded_pred)*100), "% akurasi")
# Out:
# 78.42 % akurasi
