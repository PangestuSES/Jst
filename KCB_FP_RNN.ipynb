# %%
# import library
import pandas as pd
import numpy as np
# cleaning data
from sklearn.preprocessing import LabelEncoder

# %%
# membaca data set dari file csv
from google.colab import drive
drive.mount('/content/drive')

path = "/content/drive/MyDrive/Colab Notebooks/seattle-weather.csv"
df = pd.read_csv(path)

df.head(10)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain
# 5  2012-01-06            2.5       4.4       2.2   2.2     rain
# 6  2012-01-07            0.0       7.2       2.8   2.3     rain
# 7  2012-01-08            0.0      10.0       2.8   2.0      sun
# 8  2012-01-09            4.3       9.4       5.0   3.4     rain
# 9  2012-01-10            1.0       6.1       0.6   3.4     rain

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Membuat chart untuk isi data
sns.countplot(data=df,x="weather")
plt.show();

# %%
# Melihat Persentase taget dari dataset
countrain=len(df[df.weather=="rain"])
countsun=len(df[df.weather=="sun"])
countdrizzle=len(df[df.weather=="drizzle"])
countsnow=len(df[df.weather=="snow"])
countfog=len(df[df.weather=="fog"])
print("Percent of Rain\t\t: {:.2f}%".format((countrain/(len(df.weather))*100)))
print("Percent of Sun\t\t: {:.2f}%".format((countsun/(len(df.weather))*100)))
print("Percent of Drizzle\t: {:.2f}%".format((countdrizzle/(len(df.weather))*100)))
print("Percent of Snow\t\t: {:.2f}%".format((countsnow/(len(df.weather))*100)))
print("Percent of Fog\t\t: {:.2f}%".format((countfog/(len(df.weather))*100)))
# Out:
# Percent of Rain		: 43.87%
# Percent of Sun		: 43.81%
# Percent of Drizzle	: 3.63%
# Percent of Snow		: 1.78%
# Percent of Fog		: 6.91%

# %%
#Pembulatan Precipitation
pengendapan = []

for pt in df['precipitation']:
  #tambah nilai
  pengendapan.append(round(pt))

df['precipitation-round']=pengendapan

temp_cols = df.columns.tolist()
index = df.columns.get_loc("precipitation")
pengendapan_index = df.columns.get_loc("precipitation-round")


new_cols1 = (
    temp_cols[:index] +
    temp_cols[pengendapan_index:pengendapan_index+1] +
    temp_cols[index+1:pengendapan_index]
)

df = df[new_cols1]

df.head(5)
# Out:
#          date  precipitation-round  temp_max  temp_min  wind  weather
# 0  2012-01-01                    0      12.8       5.0   4.7  drizzle
# 1  2012-01-02                   11      10.6       2.8   4.5     rain
# 2  2012-01-03                    1      11.7       7.2   2.3     rain
# 3  2012-01-04                   20      12.2       5.6   4.7     rain
# 4  2012-01-05                    1       8.9       2.8   6.1     rain

# %%
#Pembulatan temp_min
suhu_min = []

for s_min in df['temp_min']:
  #tambah nilai
  suhu_min.append(round(s_min))

df['temp_min-round']=suhu_min

temp_cols = df.columns.tolist()
index = df.columns.get_loc("temp_min")
suhu_min_index = df.columns.get_loc("temp_min-round")


new_cols2 = (
    temp_cols[:index] +
    temp_cols[suhu_min_index:suhu_min_index+1] +
    temp_cols[index+1:suhu_min_index]
)

df = df[new_cols2]

df.head(5)
# Out:
#          date  precipitation-round  temp_max  temp_min-round  wind  weather
# 0  2012-01-01                    0      12.8               5   4.7  drizzle
# 1  2012-01-02                   11      10.6               3   4.5     rain
# 2  2012-01-03                    1      11.7               7   2.3     rain
# 3  2012-01-04                   20      12.2               6   4.7     rain
# 4  2012-01-05                    1       8.9               3   6.1     rain

# %%
#Pembulatan temp_max
suhu_max = []

for s_max in df['temp_max']:
  #tambah nilai
  suhu_max.append(round(s_max))

df['temp_max-round']=suhu_max

temp_cols = df.columns.tolist()
index = df.columns.get_loc("temp_max")
suhu_max_index = df.columns.get_loc("temp_max-round")


new_cols3 = (
    temp_cols[:index] +
    temp_cols[suhu_max_index:suhu_max_index+1] +
    temp_cols[index+1:suhu_max_index]
)

df = df[new_cols3]

df.head(5)
# Out:
#          date  precipitation-round  temp_max-round  temp_min-round  wind  \
# 0  2012-01-01                    0              13               5   4.7
# 1  2012-01-02                   11              11               3   4.5
# 2  2012-01-03                    1              12               7   2.3
# 3  2012-01-04                   20              12               6   4.7
# 4  2012-01-05                    1               9               3   6.1
#
#    weather
# 0  drizzle
# 1     rain
# 2     rain
# 3     rain
# 4     rain

# %%
#Pembulatan wind
angin = []

for agn in df['wind']:
  #tambah nilai
  angin.append(round(agn))

df['wind-round']=angin

temp_cols = df.columns.tolist()
index = df.columns.get_loc("wind")
angin_index = df.columns.get_loc("wind-round")


new_cols4 = (
    temp_cols[:index] +
    temp_cols[angin_index:angin_index+1] +
    temp_cols[index+1:angin_index]
)

df = df[new_cols4]

df.head(5)
# Out:
#          date  precipitation-round  temp_max-round  temp_min-round  \
# 0  2012-01-01                    0              13               5
# 1  2012-01-02                   11              11               3
# 2  2012-01-03                    1              12               7
# 3  2012-01-04                   20              12               6
# 4  2012-01-05                    1               9               3
#
#    wind-round  weather
# 0           5  drizzle
# 1           4     rain
# 2           2     rain
# 3           5     rain
# 4           6     rain

# %%
#Slicing Bulan contoh 2012-03-01 ->
bulan = []

for bl in df['date']:
  #tambah bulan
  bulan.append(int(bl[5:7]))  #"03" -> 3

df['date-bulan']=bulan

temp_cols = df.columns.tolist()
index = df.columns.get_loc("date")
bulan_index = df.columns.get_loc("date-bulan")


new_cols5 = (
    temp_cols[:index] +
    temp_cols[bulan_index:bulan_index+1] +
    temp_cols[index+1:bulan_index]
)

df = df[new_cols5]

df.head(5)
# Out:
#    date-bulan  precipitation-round  temp_max-round  temp_min-round  \
# 0           1                    0              13               5
# 1           1                   11              11               3
# 2           1                    1              12               7
# 3           1                   20              12               6
# 4           1                    1               9               3
#
#    wind-round  weather
# 0           5  drizzle
# 1           4     rain
# 2           2     rain
# 3           5     rain
# 4           6     rain

# %%
#encoder
enc = LabelEncoder()

# weather [0 -> Drizzle, 1 -> fog, 2-> rain, 3 -> snow, 4 -> sun]
df.weather = enc.fit_transform(df.weather.values)
display(df.iloc[192])
# Out:
# date-bulan              7
# precipitation-round     0
# temp_max-round         28
# temp_min-round         13
# wind-round              3
# weather                 1
# Name: 192, dtype: int64

# %%
#data
df.head(200)
# Out:
#      date-bulan  precipitation-round  temp_max-round  temp_min-round  \
# 0             1                    0              13               5
# 1             1                   11              11               3
# 2             1                    1              12               7
# 3             1                   20              12               6
# 4             1                    1               9               3
# ..          ...                  ...             ...             ...
# 195           7                    0              25              15
# 196           7                    0              19              13
# 197           7                    0              26              13
# 198           7                    0              22              15
# 199           7                    0              21              14
#
#      wind-round  weather
# 0             5        0
# 1             4        2
# 2             2        2
# 3             5        2
# 4             6        2
# ..          ...      ...
# 195           2        2
# 196           4        2
# 197           2        2
# 198           3        4
# 199           3        4
#
# [200 rows x 6 columns]

# %%
#Mendapatkan ukuran csv
size_data = len(df)

#Membagi untuk data latih (80%)
train = round(size_data*0.8)
train_set = df[:train]


#membagi untuk data uji (20%)
test_set = df[train:]

# %%
# Alokasikan sampel data latih
x_train = train_set[[
    'date-bulan',
    'precipitation-round',
    'temp_max-round',
    'temp_min-round',
    'wind-round',
    ]].values
y_train = train_set.weather.values



type(x_train) # numpy.ndarray
# Out:
# numpy.ndarray

# %%
# Model architecture Neural Network

import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN

model = Sequential([
    SimpleRNN(units = 25, input_shape= (5,1), activation = 'elu'),
    Dense(units = 50, activation = 'elu'),
    Dense(units = 5, activation = 'softmax')
])

# %% [markdown]
# ## Fungsi aktivasi Elu menggabungkan karakteristik dari fungsi ReLU dan fungsi sigmoid. Fungsi aktivasi Elu mengatasi masalah ini dengan mengizinkan nilai negatif pada input neuron.
#
# ## Fungsi aktivasi Softmax adalah fungsi yang umum digunakan dalam jaringan saraf tiruan untuk masalah klasifikasi multikelas. Fungsi ini mengubah keluaran dari lapisan terakhir jaringan menjadi distribusi probabilitas yang menjumlahkan menjadi 1, dengan setiap elemen probabilitas yang merepresentasikan peluang kelas tertentu.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 25)                675
#
#  dense (Dense)               (None, 50)                1300
#
#  dense_1 (Dense)             (None, 5)                 255
#
# =================================================================
# Total params: 2,230
# Trainable params: 2,230
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.optimizers import Adamax

model.compile(loss = 'sparse_categorical_crossentropy', optimizer= Adamax(learning_rate = 0.0001),
              metrics = ['accuracy']
             )

# %% [markdown]
# ## Adamax: Variasi dari optimizer Adam yang lebih stabil dalam kasus jaringan dengan parameter yang besar.

# %%
# training the model
RNN_history = model.fit(x = x_train,
                        y = y_train,
                        batch_size= 10,
                        epochs = 100,
                        validation_split= 0.1,
                        shuffle = True,
                        verbose = 2)
# Out:
# Epoch 1/100
# 106/106 - 6s - loss: 1.6243 - accuracy: 0.3565 - val_loss: 1.7913 - val_accuracy: 0.2906 - 6s/epoch - 52ms/step
# Epoch 2/100
# 106/106 - 0s - loss: 1.1202 - accuracy: 0.6150 - val_loss: 1.5361 - val_accuracy: 0.3932 - 484ms/epoch - 5ms/step
# Epoch 3/100
# 106/106 - 1s - loss: 0.9836 - accuracy: 0.6673 - val_loss: 1.4213 - val_accuracy: 0.4615 - 624ms/epoch - 6ms/step
# Epoch 4/100
# 106/106 - 1s - loss: 0.9216 - accuracy: 0.6797 - val_loss: 1.3516 - val_accuracy: 0.4615 - 767ms/epoch - 7ms/step
# Epoch 5/100
# 106/106 - 1s - loss: 0.8811 - accuracy: 0.6968 - val_loss: 1.2939 - val_accuracy: 0.5128 - 621ms/epoch - 6ms/step
# Epoch 6/100
# 106/106 - 0s - loss: 0.8529 - accuracy: 0.7129 - val_loss: 1.2606 - val_accuracy: 0.5128 - 495ms/epoch - 5ms/step
# Epoch 7/100
# 106/106 - 0s - loss: 0.8303 - accuracy: 0.7177 - val_loss: 1.2204 - val_accuracy: 0.5556 - 461ms/epoch - 4ms/step
# Epoch 8/100
# 106/106 - 0s - loss: 0.8126 - accuracy: 0.7196 - val_loss: 1.1983 - val_accuracy: 0.5641 - 497ms/epoch - 5ms/step
# Epoch 9/100
# 106/106 - 0s - loss: 0.7976 - accuracy: 0.7224 - val_loss: 1.1708 - val_accuracy: 0.6154 - 459ms/epoch - 4ms/step
# Epoch 10/100
# 106/106 - 1s - loss: 0.7844 - accuracy: 0.7281 - val_loss: 1.1506 - val_accuracy: 0.6239 - 520ms/epoch - 5ms/step
# Epoch 11/100
# 106/106 - 0s - loss: 0.7738 - accuracy: 0.7386 - val_loss: 1.1348 - val_accuracy: 0.6325 - 454ms/epoch - 4ms/step
# Epoch 12/100
# 106/106 - 1s - loss: 0.7625 - accuracy: 0.7443 - val_loss: 1.1238 - val_accuracy: 0.6410 - 632ms/epoch - 6ms/step
# Epoch 13/100
# 106/106 - 1s - loss: 0.7531 - accuracy: 0.7405 - val_loss: 1.1032 - val_accuracy: 0.6410 - 530ms/epoch - 5ms/step
# Epoch 14/100
# 106/106 - 0s - loss: 0.7442 - accuracy: 0.7452 - val_loss: 1.0905 - val_accuracy: 0.6410 - 434ms/epoch - 4ms/step
# Epoch 15/100
# 106/106 - 0s - loss: 0.7348 - accuracy: 0.7452 - val_loss: 1.0769 - val_accuracy: 0.6410 - 428ms/epoch - 4ms/step
# Epoch 16/100
# 106/106 - 1s - loss: 0.7273 - accuracy: 0.7433 - val_loss: 1.0692 - val_accuracy: 0.6581 - 601ms/epoch - 6ms/step
# Epoch 17/100
# 106/106 - 1s - loss: 0.7194 - accuracy: 0.7443 - val_loss: 1.0570 - val_accuracy: 0.6496 - 662ms/epoch - 6ms/step
# Epoch 18/100
# 106/106 - 1s - loss: 0.7113 - accuracy: 0.7510 - val_loss: 1.0504 - val_accuracy: 0.6581 - 501ms/epoch - 5ms/step
# Epoch 19/100
# 106/106 - 0s - loss: 0.7046 - accuracy: 0.7519 - val_loss: 1.0363 - val_accuracy: 0.6581 - 471ms/epoch - 4ms/step
# Epoch 20/100
# 106/106 - 1s - loss: 0.6983 - accuracy: 0.7586 - val_loss: 1.0279 - val_accuracy: 0.6667 - 557ms/epoch - 5ms/step
# Epoch 21/100
# 106/106 - 1s - loss: 0.6937 - accuracy: 0.7548 - val_loss: 1.0209 - val_accuracy: 0.6667 - 842ms/epoch - 8ms/step
# Epoch 22/100
# 106/106 - 1s - loss: 0.6881 - accuracy: 0.7624 - val_loss: 1.0191 - val_accuracy: 0.6667 - 695ms/epoch - 7ms/step
# Epoch 23/100
# 106/106 - 1s - loss: 0.6843 - accuracy: 0.7605 - val_loss: 1.0150 - val_accuracy: 0.6667 - 850ms/epoch - 8ms/step
# Epoch 24/100
# 106/106 - 1s - loss: 0.6792 - accuracy: 0.7633 - val_loss: 1.0048 - val_accuracy: 0.6838 - 816ms/epoch - 8ms/step
# Epoch 25/100
# 106/106 - 1s - loss: 0.6744 - accuracy: 0.7614 - val_loss: 1.0030 - val_accuracy: 0.6752 - 830ms/epoch - 8ms/step
# Epoch 26/100
# 106/106 - 0s - loss: 0.6697 - accuracy: 0.7624 - val_loss: 0.9939 - val_accuracy: 0.6838 - 495ms/epoch - 5ms/step
# Epoch 27/100
# 106/106 - 0s - loss: 0.6661 - accuracy: 0.7690 - val_loss: 0.9977 - val_accuracy: 0.6838 - 412ms/epoch - 4ms/step
# Epoch 28/100
# 106/106 - 0s - loss: 0.6632 - accuracy: 0.7700 - val_loss: 0.9877 - val_accuracy: 0.6923 - 464ms/epoch - 4ms/step
# Epoch 29/100
# 106/106 - 0s - loss: 0.6597 - accuracy: 0.7681 - val_loss: 0.9858 - val_accuracy: 0.6923 - 462ms/epoch - 4ms/step
# Epoch 30/100
# 106/106 - 0s - loss: 0.6550 - accuracy: 0.7700 - val_loss: 0.9786 - val_accuracy: 0.6838 - 463ms/epoch - 4ms/step
# Epoch 31/100
# 106/106 - 1s - loss: 0.6521 - accuracy: 0.7709 - val_loss: 0.9716 - val_accuracy: 0.6923 - 635ms/epoch - 6ms/step
# Epoch 32/100
# 106/106 - 0s - loss: 0.6497 - accuracy: 0.7709 - val_loss: 0.9706 - val_accuracy: 0.6923 - 472ms/epoch - 4ms/step
# Epoch 33/100
# 106/106 - 1s - loss: 0.6469 - accuracy: 0.7719 - val_loss: 0.9669 - val_accuracy: 0.6923 - 622ms/epoch - 6ms/step
# Epoch 34/100
# 106/106 - 1s - loss: 0.6451 - accuracy: 0.7747 - val_loss: 0.9638 - val_accuracy: 0.6923 - 542ms/epoch - 5ms/step
# Epoch 35/100
# 106/106 - 1s - loss: 0.6416 - accuracy: 0.7747 - val_loss: 0.9577 - val_accuracy: 0.7009 - 629ms/epoch - 6ms/step
# Epoch 36/100
# 106/106 - 1s - loss: 0.6386 - accuracy: 0.7738 - val_loss: 0.9564 - val_accuracy: 0.7009 - 575ms/epoch - 5ms/step
# Epoch 37/100
# 106/106 - 0s - loss: 0.6368 - accuracy: 0.7728 - val_loss: 0.9530 - val_accuracy: 0.7009 - 474ms/epoch - 4ms/step
# Epoch 38/100
# 106/106 - 0s - loss: 0.6339 - accuracy: 0.7757 - val_loss: 0.9518 - val_accuracy: 0.7009 - 266ms/epoch - 3ms/step
# Epoch 39/100
# 106/106 - 0s - loss: 0.6314 - accuracy: 0.7766 - val_loss: 0.9506 - val_accuracy: 0.7009 - 268ms/epoch - 3ms/step
# Epoch 40/100
# 106/106 - 0s - loss: 0.6301 - accuracy: 0.7719 - val_loss: 0.9473 - val_accuracy: 0.7009 - 262ms/epoch - 2ms/step
# Epoch 41/100
# 106/106 - 0s - loss: 0.6290 - accuracy: 0.7738 - val_loss: 0.9480 - val_accuracy: 0.7009 - 258ms/epoch - 2ms/step
# Epoch 42/100
# 106/106 - 0s - loss: 0.6259 - accuracy: 0.7719 - val_loss: 0.9463 - val_accuracy: 0.7009 - 252ms/epoch - 2ms/step
# Epoch 43/100
# 106/106 - 0s - loss: 0.6245 - accuracy: 0.7747 - val_loss: 0.9451 - val_accuracy: 0.7009 - 259ms/epoch - 2ms/step
# Epoch 44/100
# 106/106 - 0s - loss: 0.6229 - accuracy: 0.7757 - val_loss: 0.9421 - val_accuracy: 0.7009 - 269ms/epoch - 3ms/step
# Epoch 45/100
# 106/106 - 0s - loss: 0.6222 - accuracy: 0.7776 - val_loss: 0.9418 - val_accuracy: 0.7009 - 269ms/epoch - 3ms/step
# Epoch 46/100
# 106/106 - 0s - loss: 0.6204 - accuracy: 0.7757 - val_loss: 0.9374 - val_accuracy: 0.7009 - 255ms/epoch - 2ms/step
# Epoch 47/100
# 106/106 - 0s - loss: 0.6178 - accuracy: 0.7700 - val_loss: 0.9361 - val_accuracy: 0.7094 - 272ms/epoch - 3ms/step
# Epoch 48/100
# 106/106 - 0s - loss: 0.6170 - accuracy: 0.7757 - val_loss: 0.9380 - val_accuracy: 0.7179 - 238ms/epoch - 2ms/step
# Epoch 49/100
# 106/106 - 0s - loss: 0.6156 - accuracy: 0.7795 - val_loss: 0.9385 - val_accuracy: 0.7179 - 249ms/epoch - 2ms/step
# Epoch 50/100
# 106/106 - 0s - loss: 0.6146 - accuracy: 0.7747 - val_loss: 0.9360 - val_accuracy: 0.7179 - 257ms/epoch - 2ms/step
# Epoch 51/100
# 106/106 - 0s - loss: 0.6134 - accuracy: 0.7747 - val_loss: 0.9360 - val_accuracy: 0.7094 - 256ms/epoch - 2ms/step
# Epoch 52/100
# 106/106 - 0s - loss: 0.6129 - accuracy: 0.7728 - val_loss: 0.9317 - val_accuracy: 0.7179 - 339ms/epoch - 3ms/step
# Epoch 53/100
# 106/106 - 0s - loss: 0.6107 - accuracy: 0.7757 - val_loss: 0.9326 - val_accuracy: 0.7094 - 433ms/epoch - 4ms/step
# Epoch 54/100
# 106/106 - 0s - loss: 0.6090 - accuracy: 0.7776 - val_loss: 0.9316 - val_accuracy: 0.7179 - 419ms/epoch - 4ms/step
# Epoch 55/100
# 106/106 - 0s - loss: 0.6072 - accuracy: 0.7747 - val_loss: 0.9287 - val_accuracy: 0.7009 - 436ms/epoch - 4ms/step
# Epoch 56/100
# 106/106 - 0s - loss: 0.6073 - accuracy: 0.7738 - val_loss: 0.9286 - val_accuracy: 0.7179 - 443ms/epoch - 4ms/step
# Epoch 57/100
# 106/106 - 0s - loss: 0.6055 - accuracy: 0.7795 - val_loss: 0.9296 - val_accuracy: 0.7179 - 427ms/epoch - 4ms/step
# Epoch 58/100
# 106/106 - 0s - loss: 0.6053 - accuracy: 0.7747 - val_loss: 0.9309 - val_accuracy: 0.7094 - 431ms/epoch - 4ms/step
# Epoch 59/100
# 106/106 - 0s - loss: 0.6036 - accuracy: 0.7814 - val_loss: 0.9282 - val_accuracy: 0.7094 - 388ms/epoch - 4ms/step
# Epoch 60/100
# 106/106 - 0s - loss: 0.6030 - accuracy: 0.7804 - val_loss: 0.9314 - val_accuracy: 0.7094 - 428ms/epoch - 4ms/step
# Epoch 61/100
# 106/106 - 0s - loss: 0.6020 - accuracy: 0.7804 - val_loss: 0.9267 - val_accuracy: 0.7179 - 365ms/epoch - 3ms/step
# Epoch 62/100
# 106/106 - 0s - loss: 0.5997 - accuracy: 0.7795 - val_loss: 0.9270 - val_accuracy: 0.6923 - 246ms/epoch - 2ms/step
# Epoch 63/100
# 106/106 - 0s - loss: 0.5996 - accuracy: 0.7823 - val_loss: 0.9251 - val_accuracy: 0.7179 - 251ms/epoch - 2ms/step
# Epoch 64/100
# 106/106 - 0s - loss: 0.5984 - accuracy: 0.7804 - val_loss: 0.9223 - val_accuracy: 0.7094 - 252ms/epoch - 2ms/step
# Epoch 65/100
# 106/106 - 0s - loss: 0.5976 - accuracy: 0.7804 - val_loss: 0.9245 - val_accuracy: 0.7094 - 256ms/epoch - 2ms/step
# Epoch 66/100
# 106/106 - 0s - loss: 0.5979 - accuracy: 0.7814 - val_loss: 0.9241 - val_accuracy: 0.7094 - 250ms/epoch - 2ms/step
# Epoch 67/100
# 106/106 - 0s - loss: 0.5967 - accuracy: 0.7814 - val_loss: 0.9209 - val_accuracy: 0.7094 - 261ms/epoch - 2ms/step
# Epoch 68/100
# 106/106 - 0s - loss: 0.5969 - accuracy: 0.7833 - val_loss: 0.9243 - val_accuracy: 0.7094 - 247ms/epoch - 2ms/step
# Epoch 69/100
# 106/106 - 0s - loss: 0.5943 - accuracy: 0.7823 - val_loss: 0.9237 - val_accuracy: 0.7179 - 257ms/epoch - 2ms/step
# Epoch 70/100
# 106/106 - 0s - loss: 0.5935 - accuracy: 0.7852 - val_loss: 0.9238 - val_accuracy: 0.7094 - 248ms/epoch - 2ms/step
# Epoch 71/100
# 106/106 - 0s - loss: 0.5928 - accuracy: 0.7852 - val_loss: 0.9207 - val_accuracy: 0.7179 - 253ms/epoch - 2ms/step
# Epoch 72/100
# 106/106 - 0s - loss: 0.5910 - accuracy: 0.7861 - val_loss: 0.9187 - val_accuracy: 0.7094 - 259ms/epoch - 2ms/step
# Epoch 73/100
# 106/106 - 0s - loss: 0.5914 - accuracy: 0.7833 - val_loss: 0.9177 - val_accuracy: 0.7179 - 267ms/epoch - 3ms/step
# Epoch 74/100
# 106/106 - 0s - loss: 0.5899 - accuracy: 0.7823 - val_loss: 0.9195 - val_accuracy: 0.7094 - 257ms/epoch - 2ms/step
# Epoch 75/100
# 106/106 - 0s - loss: 0.5900 - accuracy: 0.7842 - val_loss: 0.9208 - val_accuracy: 0.7094 - 275ms/epoch - 3ms/step
# Epoch 76/100
# 106/106 - 0s - loss: 0.5894 - accuracy: 0.7814 - val_loss: 0.9207 - val_accuracy: 0.7179 - 286ms/epoch - 3ms/step
# Epoch 77/100
# 106/106 - 0s - loss: 0.5897 - accuracy: 0.7861 - val_loss: 0.9194 - val_accuracy: 0.7094 - 260ms/epoch - 2ms/step
# Epoch 78/100
# 106/106 - 0s - loss: 0.5873 - accuracy: 0.7814 - val_loss: 0.9230 - val_accuracy: 0.7094 - 259ms/epoch - 2ms/step
# Epoch 79/100
# 106/106 - 0s - loss: 0.5874 - accuracy: 0.7823 - val_loss: 0.9188 - val_accuracy: 0.7094 - 266ms/epoch - 3ms/step
# Epoch 80/100
# 106/106 - 0s - loss: 0.5872 - accuracy: 0.7861 - val_loss: 0.9199 - val_accuracy: 0.7179 - 248ms/epoch - 2ms/step
# Epoch 81/100
# 106/106 - 0s - loss: 0.5858 - accuracy: 0.7823 - val_loss: 0.9166 - val_accuracy: 0.7094 - 271ms/epoch - 3ms/step
# Epoch 82/100
# 106/106 - 0s - loss: 0.5854 - accuracy: 0.7833 - val_loss: 0.9180 - val_accuracy: 0.7094 - 261ms/epoch - 2ms/step
# Epoch 83/100
# 106/106 - 0s - loss: 0.5848 - accuracy: 0.7871 - val_loss: 0.9140 - val_accuracy: 0.7094 - 261ms/epoch - 2ms/step
# Epoch 84/100
# 106/106 - 0s - loss: 0.5840 - accuracy: 0.7871 - val_loss: 0.9187 - val_accuracy: 0.7094 - 258ms/epoch - 2ms/step
# Epoch 85/100
# 106/106 - 0s - loss: 0.5835 - accuracy: 0.7861 - val_loss: 0.9157 - val_accuracy: 0.7179 - 271ms/epoch - 3ms/step
# Epoch 86/100
# 106/106 - 0s - loss: 0.5829 - accuracy: 0.7842 - val_loss: 0.9131 - val_accuracy: 0.7179 - 249ms/epoch - 2ms/step
# Epoch 87/100
# 106/106 - 0s - loss: 0.5825 - accuracy: 0.7871 - val_loss: 0.9155 - val_accuracy: 0.7009 - 259ms/epoch - 2ms/step
# Epoch 88/100
# 106/106 - 0s - loss: 0.5829 - accuracy: 0.7861 - val_loss: 0.9187 - val_accuracy: 0.7094 - 308ms/epoch - 3ms/step
# Epoch 89/100
# 106/106 - 0s - loss: 0.5815 - accuracy: 0.7890 - val_loss: 0.9200 - val_accuracy: 0.7094 - 250ms/epoch - 2ms/step
# Epoch 90/100
# 106/106 - 0s - loss: 0.5812 - accuracy: 0.7842 - val_loss: 0.9196 - val_accuracy: 0.7179 - 255ms/epoch - 2ms/step
# Epoch 91/100
# 106/106 - 0s - loss: 0.5803 - accuracy: 0.7852 - val_loss: 0.9143 - val_accuracy: 0.7094 - 261ms/epoch - 2ms/step
# Epoch 92/100
# 106/106 - 0s - loss: 0.5799 - accuracy: 0.7823 - val_loss: 0.9201 - val_accuracy: 0.7094 - 253ms/epoch - 2ms/step
# Epoch 93/100
# 106/106 - 0s - loss: 0.5795 - accuracy: 0.7833 - val_loss: 0.9178 - val_accuracy: 0.7179 - 260ms/epoch - 2ms/step
# Epoch 94/100
# 106/106 - 0s - loss: 0.5792 - accuracy: 0.7861 - val_loss: 0.9156 - val_accuracy: 0.7094 - 263ms/epoch - 2ms/step
# Epoch 95/100
# 106/106 - 0s - loss: 0.5778 - accuracy: 0.7842 - val_loss: 0.9167 - val_accuracy: 0.7179 - 258ms/epoch - 2ms/step
# Epoch 96/100
# 106/106 - 0s - loss: 0.5788 - accuracy: 0.7833 - val_loss: 0.9206 - val_accuracy: 0.7094 - 263ms/epoch - 2ms/step
# Epoch 97/100
# 106/106 - 0s - loss: 0.5776 - accuracy: 0.7823 - val_loss: 0.9188 - val_accuracy: 0.7009 - 260ms/epoch - 2ms/step
# Epoch 98/100
# 106/106 - 0s - loss: 0.5769 - accuracy: 0.7842 - val_loss: 0.9203 - val_accuracy: 0.7094 - 262ms/epoch - 2ms/step
# Epoch 99/100
# 106/106 - 0s - loss: 0.5765 - accuracy: 0.7852 - val_loss: 0.9177 - val_accuracy: 0.7179 - 339ms/epoch - 3ms/step
# Epoch 100/100
# 106/106 - 0s - loss: 0.5754 - accuracy: 0.7890 - val_loss: 0.9178 - val_accuracy: 0.7094 - 421ms/epoch - 4ms/step

# %%
# Grafik Perbandingan Training dan Validation
acc = RNN_history.history['accuracy']
val_acc = RNN_history.history['val_accuracy']

loss = RNN_history.history['loss']
val_loss = RNN_history.history['val_loss']

plt.figure(figsize=(12, 12))

plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy', color='r')
plt.plot(val_acc, label='Validation Accuracy', color='b')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='lower right', fontsize=13)
plt.ylabel('Accuracy', fontsize=16, weight='bold')
plt.title('RNN - Training & Validation Acc.', fontsize=16, weight='bold')
plt.xlabel('Epoch', fontsize=15, weight='bold')
plt.subplots_adjust(hspace=0.5)
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss', color='r')
plt.plot(val_loss, label='Validation Loss', color='b')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='upper right', fontsize=13)
plt.ylabel('Cross Entropy', fontsize=16, weight='bold')
plt.title('RNN - Training & Validation Loss', fontsize=15, weight='bold')
plt.xlabel('Epoch', fontsize=15, weight='bold')

plt.show()

# %%
# alokasi sampel data uji
x_test = test_set[[
    'date-bulan',
    'precipitation-round',
    'temp_max-round',
    'temp_min-round',
    'wind-round',
    ]].values
y_test = test_set.weather.values


type(x_test) # numpy.ndarray
print(x_test)
# Out:
# [[ 3 56 11  6  4]
#  [ 3  1 14  6  3]
#  [ 3  1 13  4  3]
#  ...
#  [12  0  7  1  3]
#  [12  0  6 -1  3]
#  [12  0  6 -2  4]]

# %%
# Model Prediction
predictions = model.predict(x = x_test,
                            batch_size= 10,
                            verbose=0)
print(predictions)
# Out:
# [[1.55614049e-04 2.75141152e-04 8.61934364e-01 1.37493953e-01
#   1.40976947e-04]
#  [3.38565782e-02 2.54756305e-02 7.45744944e-01 4.89531783e-03
#   1.90027475e-01]
#  [4.68043908e-02 3.07447705e-02 6.55464768e-01 8.91466811e-03
#   2.58071393e-01]
#  ...
#  [1.13944985e-01 4.15873267e-02 1.39971167e-01 1.02080032e-02
#   6.94288492e-01]
#  [1.07747696e-01 1.44067919e-02 2.77098063e-02 1.11165754e-02
#   8.39019120e-01]
#  [7.97618479e-02 5.92936715e-03 1.25011429e-02 1.47543950e-02
#   8.87053251e-01]]

# %%
# Model Evaluate
accuracy = model.evaluate(x_test, y_test)
# Out:
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6569 - accuracy: 0.8014

# %%
# Ringkasan dari metrik evaluasi
from sklearn.metrics import classification_report

y_pred = np.argmax(predictions, axis=1)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         7
#            1       0.00      0.00      0.00        31
#            2       0.98      0.83      0.90       109
#            3       0.00      0.00      0.00         0
#            4       0.73      0.99      0.84       145
#
#     accuracy                           0.80       292
#    macro avg       0.34      0.36      0.35       292
# weighted avg       0.73      0.80      0.75       292
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Menghitung nilai akurasi dengan index prediksi dengan kemungkinan tertinggi
rounded_pred = np.argmax(predictions, axis = 1)

count = 0
for i in range(len(rounded_pred)):
  row = test_set.iloc[i]
  if rounded_pred[i] == row['weather']:
    count += 1

print("%.2f" %(count/len(rounded_pred)*100), "% akurasi")
# Out:
# 80.14 % akurasi
